# %%
import sys, site, platform
print("exe:", sys.executable)
print("ver:", sys.version)
print("site:", site.getsitepackages())
# Out:
# exe: /opt/anaconda3/envs/tf_env/bin/python
# ver: 3.10.18 (main, Jun  5 2025, 08:37:47) [Clang 14.0.6 ]
# site: ['/opt/anaconda3/envs/tf_env/lib/python3.10/site-packages']

# %%
# %conda install -y -c conda-forge seaborn
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 25.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/tf_env
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aom-3.9.1                  |       h7bae524_0         2.1 MB  conda-forge
#     blas-2.136                 |         openblas          17 KB  conda-forge
#     blas-devel-3.9.0           |36_h11c0a38_openblas          17 KB  conda-forge
#     bottleneck-1.4.2           |  py310hbda83bc_0         109 KB
#     brotli-1.1.0               |       h6caf38d_4          20 KB  conda-forge
#     brotli-bin-1.1.0           |       h6caf38d_4          17 KB  conda-forge
#     ca-certificates-2025.10.5  |       hbd8a1cb_0         152 KB  conda-forge
#     cairo-1.18.4               |       h6a3b0d2_0         875 KB  conda-forge
#     certifi-2025.10.5          |     pyhd8ed1ab_0         156 KB  conda-forge
#     contourpy-1.3.1            |  py310h48ca7d4_0         249 KB
#     cycler-0.12.1              |     pyhd8ed1ab_1          13 KB  conda-forge
#     dav1d-1.2.1                |       hb547adb_0         309 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h1383a14_1         229 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     fonttools-4.60.1           |     pyh7db6752_0         809 KB  conda-forge
#     freetype-2.14.1            |       hce30654_0         169 KB  conda-forge
#     fribidi-1.0.16             |       hc919400_0          58 KB  conda-forge
#     graphite2-1.3.14           |       hec049ff_2          79 KB  conda-forge
#     harfbuzz-10.4.0            |       hb72c1af_0         1.3 MB  conda-forge
#     icu-75.1                   |       hfee45f7_0        11.3 MB  conda-forge
#     jpeg-9e                    |       h1a8c8d9_3         213 KB  conda-forge
#     kiwisolver-1.4.8           |  py310h313beb8_0          65 KB
#     lerc-4.0.0                 |       hd64df32_1         184 KB  conda-forge
#     libavif-1.3.0              |       hb06b76e_2          41 KB  conda-forge
#     libavif16-1.3.0            |       hb06b76e_2         108 KB  conda-forge
#     libblas-3.9.0              |36_h51639a9_openblas          17 KB  conda-forge
#     libbrotlicommon-1.1.0      |       h6caf38d_4          67 KB  conda-forge
#     libbrotlidec-1.1.0         |       h6caf38d_4          28 KB  conda-forge
#     libbrotlienc-1.1.0         |       h6caf38d_4         269 KB  conda-forge
#     libcblas-3.9.0             |36_hb0561ab_openblas          17 KB  conda-forge
#     libdeflate-1.22            |       hd74edd7_0          53 KB  conda-forge
#     libexpat-2.7.1             |       hec049ff_0          64 KB  conda-forge
#     libfreetype-2.14.1         |       hce30654_0           8 KB  conda-forge
#     libfreetype6-2.14.1        |       h6da58f4_0         339 KB  conda-forge
#     libgfortran-5.0.0          |14_2_0_h6c33f7e_103         153 KB  conda-forge
#     libgfortran5-14.2.0        |     h6c33f7e_103         788 KB  conda-forge
#     libglib-2.84.0             |       hdff4504_0         3.5 MB  conda-forge
#     libiconv-1.18              |       h23cfdf5_2         733 KB  conda-forge
#     libintl-0.25.1             |       h493aca8_0          89 KB  conda-forge
#     liblapack-3.9.0            |36_hd9741b5_openblas          17 KB  conda-forge
#     liblapacke-3.9.0           |36_h1b118fd_openblas          17 KB  conda-forge
#     libopenblas-0.3.30         |openmp_hf332438_0         4.0 MB  conda-forge
#     libpng-1.6.50              |       h280e0eb_1         280 KB  conda-forge
#     libwebp-base-1.6.0         |       h07db88b_0         288 KB  conda-forge
#     llvm-openmp-20.1.8         |       h4a912ad_3         276 KB  conda-forge
#     matplotlib-base-3.10.6     |  py310h066045a_0         7.0 MB
#     munkres-1.1.4              |     pyhd8ed1ab_1          15 KB  conda-forge
#     numexpr-2.11.0             |  py310h8c72970_1         166 KB
#     numpy-2.0.1                |  py310h3b2db8e_1          12 KB
#     numpy-base-2.0.1           |  py310ha9811e2_1         6.1 MB
#     openblas-0.3.30            |openmp_hea878ba_0         2.9 MB  conda-forge
#     openjpeg-2.5.3             |       h889cd5d_1         313 KB  conda-forge
#     openssl-3.5.4              |       h5503f6c_0         2.9 MB  conda-forge
#     pandas-2.3.2               |  py310h43d6402_0        11.7 MB
#     patsy-1.0.1                |     pyhd8ed1ab_1         182 KB  conda-forge
#     pcre2-10.44                |       ha881caa_2         607 KB  conda-forge
#     pillow-11.3.0              |  py310h6dd570d_0         772 KB
#     pixman-0.46.4              |       h81086ad_1         242 KB  conda-forge
#     pyparsing-3.2.5            |     pyhcf101f3_0         102 KB  conda-forge
#     python-tzdata-2025.2       |     pyhd8ed1ab_0         141 KB  conda-forge
#     pytz-2025.2                |     pyhd8ed1ab_0         185 KB  conda-forge
#     rav1e-0.7.1                |       h0716509_3         836 KB  conda-forge
#     scipy-1.15.3               |  py310h132fc3c_1        19.1 MB
#     seaborn-0.13.2             |       hd8ed1ab_3           7 KB  conda-forge
#     seaborn-base-0.13.2        |     pyhd8ed1ab_3         223 KB  conda-forge
#     statsmodels-0.14.5         |  py310h12bd487_0        10.6 MB
#     svt-av1-3.1.2              |       h12ba402_0         1.4 MB  conda-forge
#     unicodedata2-15.1.0        |  py310h80987f9_1         533 KB
#     zstd-1.5.7                 |       h6491c7d_2         391 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        98.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   aom                conda-forge/osx-arm64::aom-3.9.1-h7bae524_0
#   blas               conda-forge/osx-arm64::blas-2.136-openblas
#   blas-devel         conda-forge/osx-arm64::blas-devel-3.9.0-36_h11c0a38_openblas
#   bottleneck         pkgs/main/osx-arm64::bottleneck-1.4.2-py310hbda83bc_0
#   brotli             conda-forge/osx-arm64::brotli-1.1.0-h6caf38d_4
#   brotli-bin         conda-forge/osx-arm64::brotli-bin-1.1.0-h6caf38d_4
#   cairo              conda-forge/osx-arm64::cairo-1.18.4-h6a3b0d2_0
#   contourpy          pkgs/main/osx-arm64::contourpy-1.3.1-py310h48ca7d4_0
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_1
#   dav1d              conda-forge/osx-arm64::dav1d-1.2.1-hb547adb_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/osx-arm64::fontconfig-2.15.0-h1383a14_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fonttools          conda-forge/noarch::fonttools-4.60.1-pyh7db6752_0
#   freetype           conda-forge/osx-arm64::freetype-2.14.1-hce30654_0
#   fribidi            conda-forge/osx-arm64::fribidi-1.0.16-hc919400_0
#   graphite2          conda-forge/osx-arm64::graphite2-1.3.14-hec049ff_2
#   harfbuzz           conda-forge/osx-arm64::harfbuzz-10.4.0-hb72c1af_0
#   icu                conda-forge/osx-arm64::icu-75.1-hfee45f7_0
#   jpeg               conda-forge/osx-arm64::jpeg-9e-h1a8c8d9_3
#   kiwisolver         pkgs/main/osx-arm64::kiwisolver-1.4.8-py310h313beb8_0
#   lcms2              pkgs/main/osx-arm64::lcms2-2.16-he26ebf3_1
#   lerc               conda-forge/osx-arm64::lerc-4.0.0-hd64df32_1
#   libavif            conda-forge/osx-arm64::libavif-1.3.0-hb06b76e_2
#   libavif16          conda-forge/osx-arm64::libavif16-1.3.0-hb06b76e_2
#   libblas            conda-forge/osx-arm64::libblas-3.9.0-36_h51639a9_openblas
#   libbrotlicommon    conda-forge/osx-arm64::libbrotlicommon-1.1.0-h6caf38d_4
#   libbrotlidec       conda-forge/osx-arm64::libbrotlidec-1.1.0-h6caf38d_4
#   libbrotlienc       conda-forge/osx-arm64::libbrotlienc-1.1.0-h6caf38d_4
#   libcblas           conda-forge/osx-arm64::libcblas-3.9.0-36_hb0561ab_openblas
#   libdeflate         conda-forge/osx-arm64::libdeflate-1.22-hd74edd7_0
#   libexpat           conda-forge/osx-arm64::libexpat-2.7.1-hec049ff_0
#   libfreetype        conda-forge/osx-arm64::libfreetype-2.14.1-hce30654_0
#   libfreetype6       conda-forge/osx-arm64::libfreetype6-2.14.1-h6da58f4_0
#   libgfortran        conda-forge/osx-arm64::libgfortran-5.0.0-14_2_0_h6c33f7e_103
#   libgfortran5       conda-forge/osx-arm64::libgfortran5-14.2.0-h6c33f7e_103
#   libglib            conda-forge/osx-arm64::libglib-2.84.0-hdff4504_0
#   libiconv           conda-forge/osx-arm64::libiconv-1.18-h23cfdf5_2
#   libintl            conda-forge/osx-arm64::libintl-0.25.1-h493aca8_0
#   liblapack          conda-forge/osx-arm64::liblapack-3.9.0-36_hd9741b5_openblas
#   liblapacke         conda-forge/osx-arm64::liblapacke-3.9.0-36_h1b118fd_openblas
#   libopenblas        conda-forge/osx-arm64::libopenblas-0.3.30-openmp_hf332438_0
#   libpng             conda-forge/osx-arm64::libpng-1.6.50-h280e0eb_1
#   libtiff            pkgs/main/osx-arm64::libtiff-4.7.0-h91aec0a_0
#   libwebp-base       conda-forge/osx-arm64::libwebp-base-1.6.0-h07db88b_0
#   llvm-openmp        conda-forge/osx-arm64::llvm-openmp-20.1.8-h4a912ad_3
#   matplotlib-base    pkgs/main/osx-arm64::matplotlib-base-3.10.6-py310h066045a_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyhd8ed1ab_1
#   numexpr            pkgs/main/osx-arm64::numexpr-2.11.0-py310h8c72970_1
#   numpy              pkgs/main/osx-arm64::numpy-2.0.1-py310h3b2db8e_1
#   numpy-base         pkgs/main/osx-arm64::numpy-base-2.0.1-py310ha9811e2_1
#   openblas           conda-forge/osx-arm64::openblas-0.3.30-openmp_hea878ba_0
#   openjpeg           conda-forge/osx-arm64::openjpeg-2.5.3-h889cd5d_1
#   pandas             pkgs/main/osx-arm64::pandas-2.3.2-py310h43d6402_0
#   patsy              conda-forge/noarch::patsy-1.0.1-pyhd8ed1ab_1
#   pcre2              conda-forge/osx-arm64::pcre2-10.44-ha881caa_2
#   pillow             pkgs/main/osx-arm64::pillow-11.3.0-py310h6dd570d_0
#   pixman             conda-forge/osx-arm64::pixman-0.46.4-h81086ad_1
#   pyparsing          conda-forge/noarch::pyparsing-3.2.5-pyhcf101f3_0
#   python-tzdata      conda-forge/noarch::python-tzdata-2025.2-pyhd8ed1ab_0
#   pytz               conda-forge/noarch::pytz-2025.2-pyhd8ed1ab_0
#   rav1e              conda-forge/osx-arm64::rav1e-0.7.1-h0716509_3
#   scipy              pkgs/main/osx-arm64::scipy-1.15.3-py310h132fc3c_1
#   seaborn            conda-forge/noarch::seaborn-0.13.2-hd8ed1ab_3
#   seaborn-base       conda-forge/noarch::seaborn-base-0.13.2-pyhd8ed1ab_3
#   statsmodels        pkgs/main/osx-arm64::statsmodels-0.14.5-py310h12bd487_0
#   svt-av1            conda-forge/osx-arm64::svt-av1-3.1.2-h12ba402_0
#   unicodedata2       pkgs/main/osx-arm64::unicodedata2-15.1.0-py310h80987f9_1
#   zstd               conda-forge/osx-arm64::zstd-1.5.7-h6491c7d_2
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main/osx-arm64::ca-certificates-~ --> conda-forge/noarch::ca-certificates-2025.10.5-hbd8a1cb_0
#   certifi            pkgs/main/osx-arm64::certifi-2025.8.3~ --> conda-forge/noarch::certifi-2025.10.5-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-3.0.18-h9b4081a_0 --> conda-forge::openssl-3.5.4-h5503f6c_0
#
#
#
# Downloading and Extracting Packages:
# scipy-1.15.3         | 19.1 MB   |                                       |   0%
# pandas-2.3.2         | 11.7 MB   |                                       |   0%
#
# icu-75.1             | 11.3 MB   |                                       |   0%
#
#
# statsmodels-0.14.5   | 10.6 MB   |                                       |   0%
#
#
#
# matplotlib-base-3.10 | 7.0 MB    |                                       |   0%
#
#
#
#
# numpy-base-2.0.1     | 6.1 MB    |                                       |   0%
#
#
#
#
#
# libopenblas-0.3.30   | 4.0 MB    |                                       |   0%
#
#
#
#
#
#
# libglib-2.84.0       | 3.5 MB    |                                       |   0%
#
#
#
#
#
#
#
# openblas-0.3.30      | 2.9 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 2.9 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 1.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.4.0      | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 875 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.7.1          | 836 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fonttools-4.60.1     | 809 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-14.2.0  | 788 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 772 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 733 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.44          | 607 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# icu-75.1             | 11.3 MB   |                                       |   0%
#
#
# statsmodels-0.14.5   | 10.6 MB   |                                       |   0%
#
#
#
# matplotlib-base-3.10 | 7.0 MB    |                                       |   0%
# pandas-2.3.2         | 11.7 MB   |                                       |   0%
#
# icu-75.1             | 11.3 MB   | #####2                                |  14%
#
#
# statsmodels-0.14.5   | 10.6 MB   | ###2                                  |   9%
#
#
#
# scipy-1.15.3         | 19.1 MB   |                                       |   0%
# pandas-2.3.2         | 11.7 MB   | #5                                    |   4%
#
# icu-75.1             | 11.3 MB   | #########                             |  25%
#
#
#
# scipy-1.15.3         | 19.1 MB   | 1                                     |   0%
#
#
# statsmodels-0.14.5   | 10.6 MB   | ######2                               |  17%
# pandas-2.3.2         | 11.7 MB   | ###7                                  |  10%
#
# icu-75.1             | 11.3 MB   | ############5                         |  34%
#
#
# statsmodels-0.14.5   | 10.6 MB   | #########                             |  24%
# pandas-2.3.2         | 11.7 MB   | #####7                                |  16%
#
#
#
# scipy-1.15.3         | 19.1 MB   | 9                                     |   3%
#
#
# statsmodels-0.14.5   | 10.6 MB   | #############                         |  35%
#
#
#
# scipy-1.15.3         | 19.1 MB   | ##6                                   |   7%
# pandas-2.3.2         | 11.7 MB   | #######1                              |  19%
#
# icu-75.1             | 11.3 MB   | ###############6                      |  42%
#
#
# scipy-1.15.3         | 19.1 MB   | ####3                                 |  12%
# pandas-2.3.2         | 11.7 MB   | ########4                             |  23%
#
#
#
# matplotlib-base-3.10 | 7.0 MB    | ###########################4          |  74%
#
# icu-75.1             | 11.3 MB   | ##################6                   |  50%
#
#
# statsmodels-0.14.5   | 10.6 MB   | ######################8               |  62%
# pandas-2.3.2         | 11.7 MB   | ###########3                          |  31%
#
#
#
# scipy-1.15.3         | 19.1 MB   | #####8                                |  16%
#
#
#
# matplotlib-base-3.10 | 7.0 MB    | ##################################### | 100%
#
# icu-75.1             | 11.3 MB   | #####################2                |  57%
#
#
# scipy-1.15.3         | 19.1 MB   | #######2                              |  20%
# pandas-2.3.2         | 11.7 MB   | ##############5                       |  39%
#
#
#
#
# numpy-base-2.0.1     | 6.1 MB    |                                       |   0%
#
#
#
# scipy-1.15.3         | 19.1 MB   | ########3                             |  23%
# pandas-2.3.2         | 11.7 MB   | ################3                     |  44%
#
# icu-75.1             | 11.3 MB   | #######################5              |  64%
#
#
#
#
# numpy-base-2.0.1     | 6.1 MB    | 5                                     |   2%
#
#
# scipy-1.15.3         | 19.1 MB   | ###########1                          |  30%
# pandas-2.3.2         | 11.7 MB   | ##################7                   |  51%
#
#
#
#
# numpy-base-2.0.1     | 6.1 MB    | #2                                    |   3%
#
# icu-75.1             | 11.3 MB   | #########################5            |  69%
#
#
#
#
# numpy-base-2.0.1     | 6.1 MB    | ###2                                  |   9%
#
#
# statsmodels-0.14.5   | 10.6 MB   | ###################################4  |  96%
# scipy-1.15.3         | 19.1 MB   | #############3                        |  36%
#
#
# statsmodels-0.14.5   | 10.6 MB   | ##################################### | 100%
#
# icu-75.1             | 11.3 MB   | ###########################1          |  74%
#
#
#
#
# numpy-base-2.0.1     | 6.1 MB    | ####1                                 |  11%
# scipy-1.15.3         | 19.1 MB   | ##############7                       |  40%
#
# icu-75.1             | 11.3 MB   | #############################6        |  80%
#
#
#
#
# numpy-base-2.0.1     | 6.1 MB    | ###########7                          |  32%
# scipy-1.15.3         | 19.1 MB   | ################7                     |  45%
#
#
#
#
#
# libopenblas-0.3.30   | 4.0 MB    | 1                                     |   0%
#
# icu-75.1             | 11.3 MB   | ###############################5      |  85%
#
#
#
#
# numpy-base-2.0.1     | 6.1 MB    | ################3                     |  44%
# scipy-1.15.3         | 19.1 MB   | ##################4                   |  50%
#
#
#
#
#
# libopenblas-0.3.30   | 4.0 MB    | #####3                                |  15%
#
#
#
#
# numpy-base-2.0.1     | 6.1 MB    | ####################1                 |  54%
#
# icu-75.1             | 11.3 MB   | #################################3    |  90%
# pandas-2.3.2         | 11.7 MB   | #############################9        |  81%
#
#
#
#
#
# scipy-1.15.3         | 19.1 MB   | ###################9                  |  54%
#
#
#
#
# numpy-base-2.0.1     | 6.1 MB    | #######################8              |  64%
# pandas-2.3.2         | 11.7 MB   | ################################3     |  87%
#
#
#
#
#
# libopenblas-0.3.30   | 4.0 MB    | #################                     |  46%
#
# icu-75.1             | 11.3 MB   | ###################################   |  95%
#
#
# scipy-1.15.3         | 19.1 MB   | #####################4                |  58%
#
#
#
#
#
# libopenblas-0.3.30   | 4.0 MB    | ##################################### | 100%
# pandas-2.3.2         | 11.7 MB   | ##################################2   |  93%
#
#
#
#
#
# libopenblas-0.3.30   | 4.0 MB    | ##################################### | 100%
#
#
#
#
#
# libopenblas-0.3.30   | 4.0 MB    | ##################################### | 100%
#
#
#
#
# scipy-1.15.3         | 19.1 MB   | ######################8               |  62%
#
# icu-75.1             | 11.3 MB   | ####################################5 |  99%
#
# icu-75.1             | 11.3 MB   | ##################################### | 100%
#
#
#
#
#
#
# libglib-2.84.0       | 3.5 MB    | 1                                     |   0%
# pandas-2.3.2         | 11.7 MB   | ##################################### | 100%
# pandas-2.3.2         | 11.7 MB   | ##################################### | 100%
#
#
#
#
# scipy-1.15.3         | 19.1 MB   | ########################7             |  67%
#
#
#
#
#
#
# libglib-2.84.0       | 3.5 MB    | ######################1               |  60%
#
#
#
#
#
#
#
# openblas-0.3.30      | 2.9 MB    | 1                                     |   1%
#
#
#
#
# scipy-1.15.3         | 19.1 MB   | ##########################9           |  73%
#
#
#
#
#
#
# libglib-2.84.0       | 3.5 MB    | ##################################### | 100%
#
#
#
#
# numpy-base-2.0.1     | 6.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 2.9 MB    | 1                                     |   1%
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.1 MB    | 2                                     |   1%
#
#
#
#
#
#
#
# scipy-1.15.3         | 19.1 MB   | #############################3        |  79%
#
# icu-75.1             | 11.3 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.1 MB    | ########################1             |  65%
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 2.9 MB    | ###5                                  |  10%
#
#
#
#
#
#
#
# scipy-1.15.3         | 19.1 MB   | ###############################2      |  84%
#
#
#
#
#
#
# libglib-2.84.0       | 3.5 MB    | ##################################### | 100%
#
#
#
#
#
#
# libglib-2.84.0       | 3.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 2.9 MB    | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.1 MB    | ####################################6 |  99%
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# scipy-1.15.3         | 19.1 MB   | #################################4    |  90%
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 2.9 MB    | ##########################6           |  72%
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 1.4 MB    | 4                                     |   1%
#
#
#
#
#
#
#
# scipy-1.15.3         | 19.1 MB   | ###################################2  |  95%
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 2.9 MB    | ##################################3   |  93%
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 2.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 1.4 MB    | #############5                        |  37%
#
#
#
#
#
#
#
# scipy-1.15.3         | 19.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 2.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 1.4 MB    | #####################3                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.4.0      | 1.3 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ###############7                      |  42%
#
#
#
#
#
#
#
# openblas-0.3.30      | 2.9 MB    | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.4.0      | 1.3 MB    | ###########4                          |  31%
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 1.4 MB    | ####################################5 |  99%
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 1.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# openblas-0.3.30      | 2.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.7.1          | 836 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.4.0      | 1.3 MB    | ##################################### | 100%
#
#
#
#
# numpy-base-2.0.1     | 6.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-14.2.0  | 788 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fonttools-4.60.1     | 809 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.7.1          | 836 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 875 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 1.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-14.2.0  | 788 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 875 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 733 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fonttools-4.60.1     | 809 KB    | #######################4              |  63%
#
#
#
#
#
#
#
# openblas-0.3.30      | 2.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 772 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.44          | 607 KB    | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.44          | 607 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fonttools-4.60.1     | 809 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 772 KB    | ####################################  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 733 KB    | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.4.0      | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.4.0      | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 733 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 772 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.7.1          | 836 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.7.1          | 836 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-14.2.0  | 788 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-14.2.0  | 788 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 875 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 875 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.44          | 607 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.44          | 607 KB    | ##################################### | 100%
# pandas-2.3.2         | 11.7 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 733 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fonttools-4.60.1     | 809 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fonttools-4.60.1     | 809 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.15.3         | 19.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
